# %%
#logging with multiple loggers

import logging
#create a loggerfor module1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

#create a logger for module 2
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

#configure logging setting
logging.basicConfig(
 level = logging.DEBUG,
 format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
 datefmt = '%Y-%m-%d %H:%M:%S'
)

# %%
##log message with different loggers
logger1.debug("this is a debug message for module1")
logger2.warning("This is a warning message for moduole 2")
logger2.error("THis is an error message")
# Out:
# 2025-08-06 17:58:05 - module1 - 5(levelname)s - this is a debug message for module1
# 2025-08-06 17:58:05 - module2 - 5(levelname)s - This is a warning message for moduole 2
# 2025-08-06 17:58:05 - module2 - 5(levelname)s - THis is an error message
