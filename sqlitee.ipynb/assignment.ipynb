# %%
import sqlite3

def create_database():
    conn = sqlite3.connect('test.db')
    conn.close()
    print("Database created and sucessfully connected")

    #test the function
    create_database()

# %%
def create_table():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
